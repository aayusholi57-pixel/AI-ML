# %%
pip install --upgrade ragas langchain-core langchain-google-genai datasets
# Out:
# ...
#   Using cached ragas-0.4.3-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached langchain_core-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached langchain_google_genai-4.3.5-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached tiktoken-0.14.0-cp314-cp314-win_amd64.whl.metadata (6.8 kB)
# ...
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached instructor-1.15.4-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached scikit_network-0.33.5.tar.gz (1.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...

# %%
import os
from datasets import Dataset
from ragas import evaluate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 from datasets import Dataset
# ----> 3 from ragas import evaluate
#
# ModuleNotFoundError: No module named 'ragas'

# %%
# 1. Use the Modern RAGAS Classes
from ragas.metrics import (
    ContextPrecision,
    ContextRecall,
    Faithfulness,
    AnswerRelevancy
)

from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings

# %%
# 2. Setup your Gemini Key
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6J2L4Ex8G2CpxgDjMyhQWzBjAdUodmxiU1aRIEVo5CxqQ"

# 3. Initialize the Native Google Models
gemini_llm = ChatGoogleGenerativeAI(model="gemini-3.5-flash")
gemini_embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")

# 4. Use the NEW RAGAS v0.2+ Schema Names!
data_samples = {
    "user_input": ["What does the learning rate control?"],
    "retrieved_contexts": [["The learning rate controls how big of a step the model takes during training. It is a crucial hyperparameter."]],
    "response": ["The learning rate controls how big of a step the model takes."],
    "reference": ["It controls the step size during model training."]
}
dataset = Dataset.from_dict(data_samples)

# 5. Evaluate
result = evaluate(
    dataset=dataset,
    metrics=[
        ContextPrecision(),
        ContextRecall(),
        Faithfulness(),
        AnswerRelevancy(),
    ],
    llm=gemini_llm, 
    embeddings=gemini_embeddings 
)

print(result)
