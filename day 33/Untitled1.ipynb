# %%
# !uv pip install langchain langchain-openai langchain-chroma langchain-community langgraph pypdf tiktoken
export GEMINIAI_API_KEY="AQ.Ab8RN6LYxobf-OOxdVkEnqdgnS2iwQEWVVFHHrvfvFoy3muZMQ"
# Out:
#   Cell In[2], line 2
#     export GEMINIAI_API_KEY="AQ.Ab8RN6LYxobf-OOxdVkEnqdgnS2iwQEWVVFHHrvfvFoy3muZMQ"
#            ^
# SyntaxError: invalid syntax
