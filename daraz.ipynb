# %%
import pandas as pd

# %%
daraz = pd.read_csv("./daraz_dataset.csv")

# %%
daraz
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
daraz.shape
# Out:
# (500, 15)

# %%
daraz.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerName', 'Age', 'Gender', 'District',
#        'Category', 'Product', 'Quantity', 'UnitPrice', 'DiscountPercent',
#        'TotalAmount', 'PaymentMethod', 'Rating', 'OrderStatus'],
#       dtype='object')

# %%
daraz.iloc[0]
# Out:
# OrderID                DZ100001
# OrderDate            2026-03-04
# CustomerName       Anita Basnet
# Age                          24
# Gender                     Male
# District              Nepalgunj
# Category                 Sports
# Product                Football
# Quantity                      1
# UnitPrice                 48898
# DiscountPercent              10
# TotalAmount             44008.2
# PaymentMethod           IME Pay
# Rating                        1
# OrderStatus           Delivered
# Name: 0, dtype: object

# %%
daraz.iloc[0,2]
# Out:
# 'Anita Basnet'

# %%
daraz.loc[:,"District"]
# Out:
# 0      Nepalgunj
# 1        Pokhara
# 2       Lalitpur
# 3        Chitwan
# 4         Dharan
#          ...
# 495    Nepalgunj
# 496    Bhaktapur
# 497      Itahari
# 498       Dharan
# 499    Bhaktapur
# Name: District, Length: 500, dtype: object

# %%
daraz.loc[(daraz["District"]=="Kathmandu") & (daraz["PaymentMethod"]=="eSewa")]

# %%
daraz.sort_values("TotalAmount",ascending=False)
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 375  DZ100376  2026-02-11       Asha Thapa   18    Male   Bhaktapur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 132  DZ100133  2026-02-04         Sita Rai   52  Female   Bhaktapur
# 435  DZ100436  2026-03-20        Nabin Rai   46    Male      Butwal
# 472  DZ100473  2026-02-22       Sita Karki   42    Male   Kathmandu
# ..        ...         ...              ...  ...     ...         ...
# 94   DZ100095  2026-03-02       Roshan Rai   19    Male  Biratnagar
# 492  DZ100493  2026-05-04     Kiran Sharma   55  Female    Lalitpur
# 74   DZ100075  2026-03-18  Roshan Shrestha   49    Male      Butwal
# 195  DZ100196  2026-05-22    Manish Sharma   19  Female     Chitwan
# 27   DZ100028  2026-02-03     Rohit Basnet   46  Female     Chitwan
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 375        Books           Notebook         5      45982                0
# ...

# %%
daraz
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
#dirty data

# %%
 daraz.isnull().sum() #missing value;
daraz.fillna(0) #making zero in nan place
daraz["UnitPrice"].fillna(daraz["UnitPrice"].mean())
# Out:
# 0      48898
# 1      33418
# 2      46053
# 3      17635
# 4       3303
#        ...
# 495    47942
# 496     5707
# 497    48890
# 498     2468
# 499    38163
# Name: UnitPrice, Length: 500, dtype: int64

# %%
dummy = pd.Series(["100","200","aayush"])
pd.to_numeric(dummy,errors="coerce") #if there is alphabet in the series of number
# Out:
# 0    100.0
# 1    200.0
# 2      NaN
# dtype: float64

# %%
daraz
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
#when abc like stopped our process
pd.to_numeric(daraz["UnitPrice"],errors = "coerce")
daraz["UnitPrice"].fillna(daraz["UnitPrice"].mean())
# Out:
# 0      48898
# 1      33418
# 2      46053
# 3      17635
# 4       3303
#        ...
# 495    47942
# 496     5707
# 497    48890
# 498     2468
# 499    38163
# Name: UnitPrice, Length: 500, dtype: int64

# %%
daraz["coerce"]= pd.to_numeric(daraz["Rating"],errors = "coerce")
daraz["coerce"]= daraz["Rating"].fillna(daraz["Rating"].median())
daraz #avg rakherah treat garna ni sakinxa!
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
#drop garna nisakxa
daraz.dropna()
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
daraz.duplicated()
#duplication of data
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
#added of somethings..
daraz["District"].str.replace("%","",regex =False)
# Out:
# 0      Nepalgunj
# 1        Pokhara
# 2       Lalitpur
# 3        Chitwan
# 4         Dharan
#          ...
# 495    Nepalgunj
# 496    Bhaktapur
# 497      Itahari
# 498       Dharan
# 499    Bhaktapur
# Name: District, Length: 500, dtype: object

# %%
#outliers
