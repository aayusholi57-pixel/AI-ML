# %%
import torch

print("PyTorch version:", torch.__version__)
print("PyTorch installed successfully!")
# Out:
# PyTorch version: 2.13.0+cpu
# PyTorch installed successfully!

# %%
from sklearn.datasets import load_digits

digits = load_digits()

X = digits.images
y = digits.target

print("Before conversion:")
print(type(X))
print("Shape:", X.shape)


X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

print("\nAfter conversion:")
print(type(X_tensor))
print("Shape:", X_tensor.shape)

print("\nFirst image:")
print(X_tensor[0])

print("\nFirst label:")
print(y_tensor[0])
# Out:
# Before conversion:
# <class 'numpy.ndarray'>
# Shape: (1797, 8, 8)
#
# After conversion:
# <class 'torch.Tensor'>
# Shape: torch.Size([1797, 8, 8])
#
# First image:
# tensor([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#         [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#         [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#         [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#         [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#         [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#         [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#         [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])
#
# First label:
# tensor(0)

# %%
X_tensor = X_tensor.unsqueeze(1)
print("CNN input shape:", X_tensor.shape)
# Out:
# CNN input shape: torch.Size([1797, 1, 1, 1, 1, 1, 1, 8, 8])
