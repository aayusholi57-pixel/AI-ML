# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\python\project\industry.csv")
# Out:
# ----------------------------------------------------
# NameError          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_csv(r"D:\python\project\industry.csv")
#
# NameError: name 'pd' is not defined
