# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.
from sklearn.model_selection import train_test_split

# %%
import os

print("Current folder:", os.getcwd())
print("Files/folders:", os.listdir())
# Out:
# Current folder: E:\AI-ML\extra
# Files/folders: ['.ipynb_checkpoints', 'linearregression.ipynb', 'student_marks.csv']

# %%
import os

for root, dirs, files in os.walk(os.getcwd()):
    if "student_marks.csv" in files:
        print("Found:", os.path.join(root, "student_marks.csv"))
# Out:
# Found: E:\AI-ML\extra\student_marks.csv

# %%
df = pd.read_csv(r"E:\AI-ML\extra\student_marks.csv")
df
# Out:
#    Student  StudyHours  FinalMarks
# 0    Aarav         1.0          28
# 1   Aayush         2.0          35
# 2     Sita         2.5          40
# 3      Ram         3.0          45
# 4   Anisha         3.5          50
# 5    Rohan         4.0          55
# 6    Priya         4.5          60
# 7    Kiran         5.0          65
# 8    Nabin         5.5          70
# 9    Suman         6.0          74
# 10  Alisha         6.5          79
# 11  Bikash         7.0          84
# 12  Sabina         7.5          88
# 13  Roshan         8.0          92
# 14    Puja         9.0          98

# %%
X = df["StudyHours"].to_numpy().reshape(-1, 1)
Y = df["FinalMarks"].to_numpy()

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

model = LinearRegression()
model.fit(X_train, Y_train)

#new_students = np.array([[9]])

prediction = model.predict(X_test)

print("Predicted Final Marks:", prediction)
# Out:
# Predicted Final Marks: [73.22747415 82.47562777 26.98670606]
