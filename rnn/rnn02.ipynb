# %%
import torch
import torch.nn as nn

rnn = nn.RNN(
    input_size=1,
    hidden_size=4,
    batch_first=True
)

print(rnn)
# Out:
# RNN(1, 4, batch_first=True)

# %%
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = sequence.unsqueeze(0)
#       2
#       3 print("Input shape:", x.shape)
#       4 print(x)
#
# NameError: name 'sequence' is not defined
