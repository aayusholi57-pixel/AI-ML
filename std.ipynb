# %%
import pandas as pd

# %%
df = pd.read_csv("students.csv")

# %%
df
# Out:
#       Name  Age  Hours_Studied  Marks
# 0     Gita   18              8     96
# 1    Anita   22              3     77
# 2      Ram   18              6     72
# 3   Aayush   23              8     84
# 4     Rita   22              1     96
# ..     ...  ...            ...    ...
# 95     Ram   21              4     76
# 96  Aayush   23              4     93
# 97    Hari   18              2     83
# 98  Aayush   22              1     67
# 99  Aayush   22              6     70
#
# [100 rows x 4 columns]
