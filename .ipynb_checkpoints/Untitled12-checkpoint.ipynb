# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("student_marks.csv")
df
# Out:
#    Student  StudyHours  FinalMarks
# 0    Aarav         1.0          28
# 1   Aayush         2.0          35
# 2     Sita         2.5          40
# 3      Ram         3.0          45
# 4   Anisha         3.5          50
# 5    Rohan         4.0          55
# 6    Priya         4.5          60
# 7    Kiran         5.0          65
# 8    Nabin         5.5          70
# 9    Suman         6.0          74
# 10  Alisha         6.5          79
# 11  Bikash         7.0          84
# 12  Sabina         7.5          88
# 13  Roshan         8.0          92
# 14    Puja         9.0          98

# %%
X = df[["StudyHours"]]#features
Y = df["FinalMarks"]#labels
plt.scatter(X,Y)
plt.xlabel("Study Hours")
plt.ylabel("Final Marks")
plt.title("Study hours and final marks")
X= X.to_numpy()
y=Y.to_numpy()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 42)
model= LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predicted_Y= model.predict(X_test)
predicted_Y
# Out:
# array([73.22747415, 82.47562777, 26.98670606])

# %%
pd.DataFrame({
    "Actual": y_test,
    "Predicted":predicted_Y
})
# Out:
#    Actual  Predicted
# 0      74  73.227474
# 1      84  82.475628
# 2      28  26.986706

# %%
import numpy as np
new_students =np.array([
    [2],
    [3],
    [5],
    [8],
    [9]
])
marks_prediction = model.predict(new_students)
marks_prediction
# Out:
# array([ 36.23485968,  45.48301329,  63.97932053,  91.72378139,
#        100.97193501])
