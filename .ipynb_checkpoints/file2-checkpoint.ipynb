# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "subjet":["math","science","english", "nepali"]
    "score": {98,65,76,54}
        })
# Out:
#   Cell In[6], line 2
#     "subjet":["math","science","english", "nepali"]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
