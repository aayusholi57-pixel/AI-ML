# %%
import pandas as pd
import nummpy as np
# Out:
# ----------------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import nummpy as np
#
# ModuleNotFoundError: No module named 'nummpy'

# %%
df = pd.read_csv("D:\python\industry.csv")
